# %%
# import necessary packages
import pandas as pd
import numpy as np
import os
import title_list as tl
import char_replacement as cr
import char_list as cl

# %%
# filter to just movies I want
directory = '/Users/macambler/Documents/GitHub/NLP_Final_Project/data/script_scraping/scripts/parsed/dialogue'

movie_files = []
for filename in os.listdir(directory):
    title = filename[:-13]
    if title in tl.title_list:
        movie_files.append(filename)
movie_files.sort()

# %%
# load dialogue from movies into dataframe
df = pd.DataFrame(columns=['title','line'])

for filename in movie_files:
    f = os.path.join(directory, filename)
    file = open(f, 'r')
    while True:
        line = file.readline()
        if not line:
            break
        df = pd.concat([df, pd.DataFrame({'title': [filename[:-13]], 'line': [line]})], ignore_index=True)

# %%
# split the lines into character and dialogue
# put these characters and dialogue into separate dataframe columns
df['character'] = ''
df['dialogue'] = ''
for i, line in enumerate(df['line']):
    df['character'][i] = df['line'][i].split('=>')[0]
    df['line'][i] = df['line'][i].replace('\n','')
    df['dialogue'][i] = df['line'][i].split('=>')[1]

# %%
# drop the original lines
parsed_df = df.drop(columns=['line'])
parsed_df
# Out:
#                   title         character  \
# 0                Avatar             VOICE
# 1                Avatar             VOICE
# 2                Avatar              JAKE
# 3                Avatar  PERKY NEWSCASTER
# 4                Avatar              JAKE
# ...                 ...               ...
# 37856  Wizard-of-Oz-The           DOROTHY
# 37857  Wizard-of-Oz-The           DOROTHY
# 37858  Wizard-of-Oz-The       UNCLE HENRY
# 37859  Wizard-of-Oz-The           DOROTHY
# 37860  Wizard-of-Oz-The           DOROTHY
#
#                                                 dialogue
# 0      When I was lying there in the VA hospital, wit...
# 1      Sooner or later though, you always have to wak...
# 2      They can fix a spinal, if you've got the money...
# 3      The Bengal tiger, extinct for over a century, ...
# 4      I became a Marine for the hardship. To be hamm...
# ...                                                  ...
# 37856  ...but most of it was beautiful. But just the ...
# 37857                        Doesn't anybody believe me?
# 37858                 Of course we believe you, Dorothy.
# 37859                  Oh, but anyway, Toto, we're home!
# 37860  Home! And this is my room -- and you're all he...
#
# [37861 rows x 3 columns]

# %%
# use the user-built character replacement list
# to replace any inconsistent character names or those with typos
for i in cr.char_replacement_ls:
    parsed_df['character'] = parsed_df['character'].str.replace(i[0],i[1])

# %%
# filter the characters to just those in user built character list
filtered_df = parsed_df[parsed_df['character'].isin(cl.char_list)].reset_index(drop=True)
filtered_df
# Out:
#                   title character  \
# 0                Avatar      JAKE
# 1                Avatar      JAKE
# 2                Avatar      JAKE
# 3                Avatar      JAKE
# 4                Avatar      JAKE
# ...                 ...       ...
# 26999  Wizard-of-Oz-The   DOROTHY
# 27000  Wizard-of-Oz-The   DOROTHY
# 27001  Wizard-of-Oz-The   DOROTHY
# 27002  Wizard-of-Oz-The   DOROTHY
# 27003  Wizard-of-Oz-The   DOROTHY
#
#                                                 dialogue
# 0      They can fix a spinal, if you've got the money...
# 1      I became a Marine for the hardship. To be hamm...
# 2      Let's get it straight up front. I don't want y...
# 3      You want a fair deal, you're on the wrong plan...
# 4      It's just the way things are. And nobody does ...
# ...                                                  ...
# 26999  No, Aunt Em -- this was a real, truly live pla...
# 27000  ...but most of it was beautiful. But just the ...
# 27001                        Doesn't anybody believe me?
# 27002                  Oh, but anyway, Toto, we're home!
# 27003  Home! And this is my room -- and you're all he...
#
# [27004 rows x 3 columns]

# %%
# group by character and count lines of dialogue
table = filtered_df.groupby(['character']).count()
table
# Out:
#                   title  dialogue
# character
# AGENT MARIA HILL     22        22
# AGENT SMITH          74        74
# AGNES                65        65
# ALAN                226       226
# ALFRED               69        69
# ...                 ...       ...
# WINSTON              31        31
# WITCH                49        49
# YODA                 75        75
# YONDU                82        82
# ZURI                 26        26
#
# [275 rows x 2 columns]

# %%
# find only the characters with at least 100 lines of dialogue
most_lines_chars = table[table['dialogue']>=100].index.get_level_values('character')

# %%
most_lines_chars
# Out:
# Index(['ALAN', 'ANAKIN', 'ANDREW', 'ANNA', 'ARAGORN', 'BATMAN', 'BELLA',
#        'BELLE', 'BENDER', 'BRIAN', 'C-3PO', 'CAMERON', 'CAPTAIN AMERICA',
#        'CARL', 'CARTMAN', 'CLAIRE', 'DONKEY', 'DOROTHY', 'DORY', 'EDWARD',
#        'ELIZABETH', 'ELLIE', 'ELSA', 'EVAN', 'FERRIS', 'FINN', 'FIONA',
#        'FOGELL', 'FORREST', 'FOX', 'FRODO', 'GAMORA', 'GANDALF', 'GEORGE',
#        'GRACE', 'GRANT', 'GRU', 'HAN', 'HARRY', 'HENRY', 'HICCUP', 'HOLLEY',
#        'HÉCTOR', 'INDY', 'INIGO', 'IRON MAN', 'JACK', 'JAKE', 'JANE', 'JENNY',
#        'KRISTOFF', 'KYLE', 'LEIA', 'LION', 'LLOYD', 'LOKI', 'LUCY', 'LUKE',
#        'LUMIÈRE', 'MARLIN', 'MARY', 'MATER', 'MCQUEEN', 'MIGUEL', 'MORPHEUS',
#        'NEMO', 'NEO', 'NICK FURY', 'OBI-WAN', 'OLAF', 'PADME', 'PETER', 'PHIL',
#        'PO', 'QUILL', 'REY', 'ROCKET', 'RUSSELL', 'SAM', 'SCARECROW', 'SETH',
#        'SHIFU', 'SHREK', 'SLOANE', 'STAN', 'STOICK', 'STU', 'T'CHALLA', 'THOR',
#        'TIN MAN', 'VALJEAN', 'WILLIE'],
#       dtype='object', name='character')

# %%
# filter to only these characters
final_df = filtered_df[filtered_df['character'].isin(most_lines_chars)].reset_index(drop=True)
final_df
# Out:
#                   title character  \
# 0                Avatar      JAKE
# 1                Avatar      JAKE
# 2                Avatar      JAKE
# 3                Avatar      JAKE
# 4                Avatar      JAKE
# ...                 ...       ...
# 18923  Wizard-of-Oz-The   DOROTHY
# 18924  Wizard-of-Oz-The   DOROTHY
# 18925  Wizard-of-Oz-The   DOROTHY
# 18926  Wizard-of-Oz-The   DOROTHY
# 18927  Wizard-of-Oz-The   DOROTHY
#
#                                                 dialogue
# 0      They can fix a spinal, if you've got the money...
# 1      I became a Marine for the hardship. To be hamm...
# 2      Let's get it straight up front. I don't want y...
# 3      You want a fair deal, you're on the wrong plan...
# 4      It's just the way things are. And nobody does ...
# ...                                                  ...
# 18923  No, Aunt Em -- this was a real, truly live pla...
# 18924  ...but most of it was beautiful. But just the ...
# 18925                        Doesn't anybody believe me?
# 18926                  Oh, but anyway, Toto, we're home!
# 18927  Home! And this is my room -- and you're all he...
#
# [18928 rows x 3 columns]

# %%
# write the dataframe to a csv
final_df.to_csv('../data/processed_char_dialogue.csv')
