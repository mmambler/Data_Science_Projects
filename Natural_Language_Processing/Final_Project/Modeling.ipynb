# %%
# import any and all necessary packages
import os
import pandas as pd
import numpy as np
import operator
from scipy.stats import randint
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.calibration import CalibratedClassifierCV

# %%
# load in the dataframe
df = pd.read_csv('/content/drive/MyDrive/NLP/Final Project/processed_char_dialogue.csv')
df.drop(columns=df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#     title character                                           dialogue
# 0  Avatar      JAKE  They can fix a spinal, if you've got the money...
# 1  Avatar      JAKE  I became a Marine for the hardship. To be hamm...
# 2  Avatar      JAKE  Let's get it straight up front. I don't want y...
# 3  Avatar      JAKE  You want a fair deal, you're on the wrong plan...
# 4  Avatar      JAKE  It's just the way things are. And nobody does ...

# %%
# filter to only the top 50 characters by lines of dialogue
table = df.groupby(['character']).count()
table_50 = table.sort_values(by='dialogue', ascending=False).head(50)
df = df[df['character'].isin(table_50.index)].reset_index(drop=True)

# %%
# create two dictionaries to convert character names to and from their IDs
char_list = df['character'].unique()
class_ids = []
class_to_id_dict = {}
id_to_class_dict = {}
for i, char in enumerate(char_list):
  class_ids.append(i)
  class_to_id_dict[char] = i
  id_to_class_dict[i] = char

# %%
# map character names to IDs
df['character'] = df['character'].map(class_to_id_dict)

# %%
# define X and Y
X, y = df['dialogue'].values, df['character'].values

# %%
# Vectorize the dialogue using the TF-IDF vectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2),
                        stop_words='english')

X = tfidf.fit_transform(X).toarray()
print("Each of the %d lines of dialogue is represented by %d features (TF-IDF score of unigrams and bigrams)" %(X.shape))
# Out:
# Each of the 13256 lines of dialogue is represented by 2490 features (TF-IDF score of unigrams and bigrams)

# %%
# fix class imbalance using SMOTE to create synthetic data
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
# Find the three most correlated unigrams and bigrams with each of the characters
N = 3
for Class, ID in sorted(class_to_id_dict.items()):
  features_chi2 = chi2(X, y == ID)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names_out())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("===> %s:" %(Class))
  print("  * Most Correlated Unigrams are: %s" %(', '.join(unigrams[-N:])))
  print("  * Most Correlated Bigrams are: %s" %(', '.join(bigrams[-N:])))
# Out:
# ===> ALAN:
#   * Most Correlated Unigrams are: tracy, vick, doug
#   * Most Correlated Bigrams are: chastity smiles, vick nods, oh god
# ===> ANAKIN:
#   * Most Correlated Unigrams are: mom, padme, master
#   * Most Correlated Bigrams are: don don, obi wan, sorry master
# ===> ANNA:
#   * Most Correlated Unigrams are: olaf, kristoff, elsa
#   * Most Correlated Bigrams are: north mountain, time forever, frozen lee
# ===> BATMAN:
#   * Most Correlated Unigrams are: lucius, alfred, bane
#   * Most Correlated Bigrams are: trying kill, wouldn want, bruce wayne
# ===> BELLA:
#   * Most Correlated Unigrams are: prom, mom, edward
#   * Most Correlated Bigrams are: trying kill, sounds like, did know
# ===> BENDER:
#   * Most Correlated Unigrams are: question, genius, claire
#   * Most Correlated Bigrams are: old man, guy like, yeah got
# ===> C-3PO:
#   * Most Correlated Unigrams are: chewbacca, goodness, artoo
#   * Most Correlated Bigrams are: princess leia, oh dear, master luke
# ===> CARL:
#   * Most Correlated Unigrams are: carl, ellie, russell
#   * Most Correlated Bigrams are: don touch, paradise falls, carl russell
# ===> DONKEY:
#   * Most Correlated Unigrams are: aah, princess, shrek
#   * Most Correlated Bigrams are: hey wait, oh know, really really
# ===> DOROTHY:
#   * Most Correlated Unigrams are: auntie, oh, toto
#   * Most Correlated Bigrams are: aunt em, oh oh, auntie em
# ===> DORY:
#   * Most Correlated Unigrams are: sherman, sydney, 42
#   * Most Correlated Bigrams are: way sydney, 42 wallaby, wallaby way
# ===> EDWARD:
#   * Most Correlated Unigrams are: future, lion, bella
#   * Most Correlated Bigrams are: didn want, don just, going let
# ===> ELSA:
#   * Most Correlated Unigrams are: brody, indy, anna
#   * Most Correlated Bigrams are: frozen lee, stay away, let let
# ===> EVAN:
#   * Most Correlated Unigrams are: seth, fogell, helen
#   * Most Correlated Bigrams are: uh uh, oh man, bang bus
# ===> FERRIS:
#   * Most Correlated Unigrams are: alot, cash, cameron
#   * Most Correlated Bigrams are: yeah really, ll pay, high school
# ===> FINN:
#   * Most Correlated Unigrams are: rey, finn, mater
#   * Most Correlated Bigrams are: just happened, know happened, good job
# ===> FORREST:
#   * Most Correlated Unigrams are: bubba, momma, jenny
#   * Most Correlated Bigrams are: ping pong, forrest gump, lieutenant dan
# ===> FOX:
#   * Most Correlated Unigrams are: ash, kylie, fox
#   * Most Correlated Bigrams are: fox kylie, mr wayne, mrs fox
# ===> FRODO:
#   * Most Correlated Unigrams are: sméagol, gandalf, sam
#   * Most Correlated Bigrams are: ll ll, don hurt, come sam
# ===> GANDALF:
#   * Most Correlated Unigrams are: peregrin, ring, saruman
#   * Most Correlated Bigrams are: did tell, frodo ring, peregrin took
# ===> GEORGE:
#   * Most Correlated Unigrams are: clarence, potter, mary
#   * Most Correlated Bigrams are: uncle billy, mary mary, mr potter
# ===> GRU:
#   * Most Correlated Unigrams are: agnes, lucy, margo
#   * Most Correlated Bigrams are: ken draft, el macho, dr nefario
# ===> HAN:
#   * Most Correlated Unigrams are: luke, lando, chewie
#   * Most Correlated Bigrams are: kylo ren, oh great, ll time
# ===> HARRY:
#   * Most Correlated Unigrams are: nah, briefcase, lloyd
#   * Most Correlated Bigrams are: gonna say, know got, know lloyd
# ===> HICCUP:
#   * Most Correlated Unigrams are: astrid, toothless, hiccup
#   * Most Correlated Bigrams are: monstrous nightmare, hiccup toothless, red death
# ===> HÉCTOR:
#   * Most Correlated Unigrams are: amigo, imelda, chamaco
#   * Most Correlated Bigrams are: great grandpa, just wanted, cross bridge
# ===> INDY:
#   * Most Correlated Unigrams are: ark, dad, willie
#   * Most Correlated Bigrams are: man pass, penitent man, short round
# ===> JACK:
#   * Most Correlated Unigrams are: turner, black, pearl
#   * Most Correlated Bigrams are: know going, right way, black pearl
# ===> JAKE:
#   * Most Correlated Unigrams are: forest, neytiri, grace
#   * Most Correlated Bigrams are: man pass, stop stop, ve gotta
# ===> KRISTOFF:
#   * Most Correlated Unigrams are: anna, ice, sven
#   * Most Correlated Bigrams are: ve got, just met, frozen lee
# ===> LEIA:
#   * Most Correlated Unigrams are: cave, luke, han
#   * Most Correlated Bigrams are: light speed, good luck, don say
# ===> LLOYD:
#   * Most Correlated Unigrams are: barney, har, harry
#   * Most Correlated Bigrams are: uh oh, come man, wait second
# ===> LOKI:
#   * Most Correlated Unigrams are: odin, loki, thor
#   * Most Correlated Bigrams are: shakes head, loki looks, ve come
# ===> LUCY:
#   * Most Correlated Unigrams are: tumnus, edmund, gru
#   * Most Correlated Bigrams are: despicable cinco, ken draft, mr tumnus
# ===> LUKE:
#   * Most Correlated Unigrams are: yoda, artoo, ben
#   * Most Correlated Bigrams are: just hang, ve learned, ll meet
# ===> MARLIN:
#   * Most Correlated Unigrams are: son, nemo, dory
#   * Most Correlated Bigrams are: okay right, speak whale, dory dory
# ===> MARY:
#   * Most Correlated Unigrams are: darling, bailey, george
#   * Most Correlated Bigrams are: did come, beg pardon, george bailey
# ===> MATER:
#   * Most Correlated Unigrams are: tow, dadgum, mcqueen
#   * Most Correlated Bigrams are: ain gonna, tow truck, ice cream
# ===> MIGUEL:
#   * Most Correlated Unigrams are: cruz, héctor, dante
#   * Most Correlated Bigrams are: great great, mamá coco, la cruz
# ===> NEO:
#   * Most Correlated Unigrams are: fuck, shit, morpheus
#   * Most Correlated Bigrams are: did did, did know, oh shit
# ===> PHIL:
#   * Most Correlated Unigrams are: doug, stu, alan
#   * Most Correlated Bigrams are: alan just, exchange look, jimmy lang
# ===> PO:
#   * Most Correlated Unigrams are: noodles, kung, shifu
#   * Most Correlated Bigrams are: kung fu, master shifu, dragon warrior
# ===> QUILL:
#   * Most Correlated Unigrams are: gamora, boring, yondu
#   * Most Correlated Bigrams are: like old, ll minute, don need
# ===> RUSSELL:
#   * Most Correlated Unigrams are: snipe, fredricksen, kevin
#   * Most Correlated Bigrams are: want help, wilderness explorer, mr fredricksen
# ===> SAM:
#   * Most Correlated Unigrams are: haw, mr, frodo
#   * Most Correlated Bigrams are: don mean, hee haw, mr frodo
# ===> SETH:
#   * Most Correlated Unigrams are: evan, fucking, jules
#   * Most Correlated Bigrams are: yeah really, holy shit, look good
# ===> SHREK:
#   * Most Correlated Unigrams are: fiona, swamp, donkey
#   * Most Correlated Bigrams are: really really, think maybe, gonna eat
# ===> STU:
#   * Most Correlated Unigrams are: doug, alan, vick
#   * Most Correlated Bigrams are: oh god, alan looks, vick just
# ===> THOR:
#   * Most Correlated Unigrams are: selvig, thor, loki
#   * Most Correlated Bigrams are: come home, frost giants, thor looks
# ===> WILLIE:
#   * Most Correlated Unigrams are: dr, jones, indy
#   * Most Correlated Bigrams are: think need, want home, dr jones

# %%
# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state = 0)

# %%
# define 5 different models to build and test
models = [
    RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0),
    CalibratedClassifierCV(LinearSVC()),
    MultinomialNB(),
    LogisticRegression(random_state=0, max_iter=1000),
]
# perform 5 fold cross-validation on each model
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, X, y, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %%
# view the accuracies of each fold
cv_df
# Out:
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.180285
# 1   RandomForestClassifier         1  0.201946
# 2   RandomForestClassifier         2  0.192477
# 3   RandomForestClassifier         3  0.202594
# 4   RandomForestClassifier         4  0.196368
# 5   CalibratedClassifierCV         0  0.501816
# 6   CalibratedClassifierCV         1  0.528275
# 7   CalibratedClassifierCV         2  0.595720
# 8   CalibratedClassifierCV         3  0.600130
# 9   CalibratedClassifierCV         4  0.613489
# 10           MultinomialNB         0  0.426200
# 11           MultinomialNB         1  0.451102
# 12           MultinomialNB         2  0.520233
# 13           MultinomialNB         3  0.523217
# 14           MultinomialNB         4  0.542802
# 15      LogisticRegression         0  0.419455
# 16      LogisticRegression         1  0.446044
# 17      LogisticRegression         2  0.487808
# 18      LogisticRegression         3  0.494163
# 19      LogisticRegression         4  0.505318

# %%
# once more, fit the data to the highest performing model
model = CalibratedClassifierCV(LinearSVC())
trained_model = model.fit(X_train, y_train)

# %%
import pickle

# Save the model to a file using Pickle
with open('char_class_model.pkl', 'wb') as f:
    pickle.dump(trained_model, f)
